# %% [markdown]
# <a href="https://colab.research.google.com/github/otmive/diffusion_classifier_clip/blob/main/clip_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-olrbk8tl
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-olrbk8tl
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Single Object

# %%
# !cp /content/drive/MyDrive/single_object\ \(4\).zip /content/single_object.zip
# !unzip single_object.zip
# Out:
# Archive:  single_object.zip
#    creating: single_object/
#    creating: single_object/val/
#    creating: single_object/val/gray cylinder/
#   inflating: single_object/val/gray cylinder/CLEVR_new_small_gray_rubber_cylinder000068.png
#   inflating: single_object/val/gray cylinder/CLEVR_new_small_gray_rubber_cylinder000082.png
#   inflating: single_object/val/gray cylinder/CLEVR_new_small_gray_rubber_cylinder000035.png
#   inflating: single_object/val/gray cylinder/CLEVR_new_large_gray_rubber_cylinder000096.png
#   inflating: single_object/val/gray cylinder/CLEVR_new_small_gray_metal_cylinder000073.png
#   inflating: single_object/val/gray cylinder/CLEVR_new_small_gray_metal_cylinder000075.png
#   inflating: single_object/val/gray cylinder/CLEVR_new_large_gray_metal_cylinder000017.png
#   inflating: single_object/val/gray cylinder/CLEVR_new_large_gray_metal_cylinder000036.png
#   inflating: single_object/val/gray cylinder/CLEVR_new_small_gray_rubber_cylinder000014.png
# ...

# %%
# !cp /content/drive/MyDrive/clip_5_seed_single_models-20240723T132309Z-001.zip /content/
# !unzip clip_5_seed_single_models-20240723T132309Z-001.zip
# Out:
# Archive:  clip_5_seed_single_models-20240723T132309Z-001.zip
#   inflating: clip_5_seed_single_models/clip_single_5.pt
#   inflating: clip_5_seed_single_models/clip_single_4.pt
#   inflating: clip_5_seed_single_models/clip_single_3.pt
#   inflating: clip_5_seed_single_models/clip_single_2.pt
#   inflating: clip_5_seed_single_models/clip_single_1.pt

# %%
# get 2 images for each class in train that model hasn't seen
# !cp /content/drive/MyDrive/train30.zip /content/
# !unzip train30.zip
# Out:
# Archive:  train30.zip
#    creating: train30/
#    creating: train30/yellow sphere/
#   inflating: train30/yellow sphere/CLEVR_new_large_yellow_metal_sphere000088.png
#   inflating: train30/yellow sphere/CLEVR_new_small_yellow_metal_sphere000095.png
#   inflating: train30/yellow sphere/CLEVR_new_large_yellow_metal_sphere000024.png
#   inflating: train30/yellow sphere/CLEVR_new_large_yellow_rubber_sphere000059.png
#   inflating: train30/yellow sphere/CLEVR_new_large_yellow_rubber_sphere000076.png
#   inflating: train30/yellow sphere/CLEVR_new_large_yellow_rubber_sphere000033.png
#   inflating: train30/yellow sphere/CLEVR_new_small_yellow_metal_sphere000001.png
#   inflating: train30/yellow sphere/CLEVR_new_small_yellow_metal_sphere000039.png
#   inflating: train30/yellow sphere/CLEVR_new_small_yellow_rubber_sphere000011.png
#   inflating: train30/yellow sphere/CLEVR_new_large_yellow_metal_sphere000015.png
# ...

# %%
dest = "unseen70"
unseencount = 0
seencount = 0
import os
import glob
import shutil
for folder in os.listdir("single_object/train/"):
  print(folder)
  dest_folder = dest + "/" + folder
  if not os.path.exists(dest_folder):
    os.makedirs(dest_folder)
  seen_images = [f for f in os.listdir("train30/" + folder + "/")]
  print(seen_images)
  for img in os.listdir("single_object/train/" + folder):
    print(img)
    if img not in seen_images:
      shutil.copy("single_object/train/" + folder + "/" + img, dest_folder + "/" + img)
      unseencount +=1
    else:
      print("already seen")
      seencount += 1
print(unseencount)
print(seencount)
# Out:
# cyan cylinder
# ...

# %%
# !rm -r single_object/test/.ipynb_checkpoints

# %%
import clip
import torch
from PIL import Image
import glob
import os
import pandas as pd

def argmax(iterable):
    return max(enumerate(iterable), key=lambda x: x[1])[0]

device = "cuda" if torch.cuda.is_available() else "cpu"
model, transform = clip.load("ViT-B/32", device=device)
model.load_state_dict(torch.load("/content/drive/MyDrive/8batch_model5.pt"))

class_names = []
for folder in os.listdir("single_object/val/"):
  class_names.append(folder)
print(class_names)

classes = pd.read_csv("clevr_prompts_cone.csv")['class_name'].tolist()
#candidate_names = ["blue cone", "blue cylinder", "brown cylinder", "cyan cube", "gray cone", "green cone", "green cube", "purple cube", "red cone", "red cube", "yellow cylinder"]
candidate_captions = [f"a photo of a {cls}" for cls in classes]
print(candidate_captions)
correct = []
#define our target classificaitons, you can should experiment with these strings of text as you see fit, though, make sure they are in the same order as your class names above
text = clip.tokenize(candidate_captions).to(device)

rows_list = []

for cls in class_names:
    print(cls)
    class_correct = []
    test_imgs = glob.glob('single_object/val/' + cls + '/*.png')
    for img in test_imgs:
        #print("here")
        #print(img)
        image = transform(Image.open(img)).unsqueeze(0).to(device)
        with torch.no_grad():
            image_features = model.encode_image(image)
            text_features = model.encode_text(text)

            logits_per_image, logits_per_text = model(image, text)
            probs = logits_per_image.softmax(dim=-1).cpu().numpy()

            pred = classes[argmax(list(probs)[0])]

            dict1 = {'true': cls, 'pred': pred}
            rows_list.append(dict1)
            if pred == cls:
                correct.append(1)
                class_correct.append(1)
            else:
                correct.append(0)
                class_correct.append(0)
                print(img)


    print('accuracy on class ' + cls + ' is :' + str(sum(class_correct)/len(class_correct)))
print('accuracy on all is : ' + str(sum(correct)/len(correct)))

df = pd.DataFrame(rows_list)
df.to_csv('clip_ft_val_5.csv')
# Out:
# ['brown sphere', 'yellow cube', 'gray cylinder', 'cyan cone']
# ['a photo of a blue cone', 'a photo of a blue cube', 'a photo of a blue cylinder', 'a photo of a blue sphere', 'a photo of a brown cone', 'a photo of a brown cube', 'a photo of a brown cylinder', 'a photo of a brown sphere', 'a photo of a cyan cone', 'a photo of a cyan cube', 'a photo of a cyan cylinder', 'a photo of a cyan sphere', 'a photo of a gray cone', 'a photo of a gray cube', 'a photo of a gray cylinder', 'a photo of a gray sphere', 'a photo of a green cone', 'a photo of a green cube', 'a photo of a green cylinder', 'a photo of a green sphere', 'a photo of a purple cone', 'a photo of a purple cube', 'a photo of a purple cylinder', 'a photo of a purple sphere', 'a photo of a red cone', 'a photo of a red cube', 'a photo of a red cylinder', 'a photo of a red sphere', 'a photo of a yellow cone', 'a photo of a yellow cube', 'a photo of a yellow cylinder', 'a photo of a yellow sphere']
# brown sphere
# ...

# %% [markdown]
# # Two object

# %%
# !!cp /content/drive/MyDrive/two_object\ \(3\).zip /content/two_object.zip
# !unzip two_object.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: two_object/train/cyan_cylinder_blue_cube/cyan cylinder/CLEVR_blue_cube_cyan_cylinder_000154.png
#   inflating: two_object/train/cyan_cylinder_blue_cube/cyan cylinder/CLEVR_blue_cube_cyan_cylinder_000198.png
#   inflating: two_object/train/cyan_cylinder_blue_cube/cyan cylinder/CLEVR_blue_cube_cyan_cylinder_000185.png
#   inflating: two_object/train/cyan_cylinder_blue_cube/cyan cylinder/CLEVR_blue_cube_cyan_cylinder_000166.png
#   inflating: two_object/train/cyan_cylinder_blue_cube/cyan cylinder/CLEVR_blue_cube_cyan_cylinder_000164.png
#   inflating: two_object/train/cyan_cylinder_blue_cube/cyan cylinder/CLEVR_blue_cube_cyan_cylinder_000177.png
#   inflating: two_object/train/cyan_cylinder_blue_cube/cyan cylinder/CLEVR_blue_cube_cyan_cylinder_000175.png
#    creating: two_object/train/purple_cylinder_brown_cone/
#    creating: two_object/train/purple_cylinder_brown_cone/purple cylinder/
# ...

# %%
# !cp /content/drive/MyDrive/trainTwo30.zip /content/
# !unzip trainTwo30.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/trainTwo30/brown_cone_cyan_cylinder/brown cone/CLEVR_cyan_cylinder_brown_cone_004987.png
#   inflating: content/trainTwo30/brown_cone_cyan_cylinder/brown cone/CLEVR_cyan_cylinder_brown_cone_004985.png
#   inflating: content/trainTwo30/brown_cone_cyan_cylinder/brown cone/CLEVR_cyan_cylinder_brown_cone_004979.png
#   inflating: content/trainTwo30/brown_cone_cyan_cylinder/brown cone/CLEVR_cyan_cylinder_brown_cone_004974.png
#   inflating: content/trainTwo30/brown_cone_cyan_cylinder/brown cone/CLEVR_cyan_cylinder_brown_cone_004999.png
#   inflating: content/trainTwo30/brown_cone_cyan_cylinder/brown cone/CLEVR_cyan_cylinder_brown_cone_004952.png
#   inflating: content/trainTwo30/brown_cone_cyan_cylinder/brown cone/CLEVR_cyan_cylinder_brown_cone_004953.png
#   inflating: content/trainTwo30/brown_cone_cyan_cylinder/brown cone/CLEVR_cyan_cylinder_brown_cone_004967.png
# ...

# %%
dest = "unseen30"
unseencount = 0
seencount = 0
import os
import glob
import shutil
for folder in os.listdir("two_object/train/"):
  print(folder)
  subfolder = os.listdir("two_object/train/" + folder)[0]
  print(subfolder)
  dest_folder = dest + "/" + folder + "/" + subfolder
  if not os.path.exists(dest_folder):
    os.makedirs(dest_folder)
  seen_images = [f for f in os.listdir("trainTwo30/" + folder + "/" + subfolder)]
  print(seen_images)
  for img in os.listdir("two_object/train/" + folder + "/" + subfolder):
    print(img)
    if img not in seen_images:
      shutil.copy("two_object/train/" + folder + "/" + subfolder + "/" + img, dest_folder + "/" + img)
      unseencount +=1
    else:
      print("already seen")
      seencount += 1
print(unseencount)
print(seencount)
# Out:
# Streaming output truncated to the last 5000 lines.
# already seen
# CLEVR_yellow_sphere_brown_cube_015956.png
# already seen
# CLEVR_yellow_sphere_brown_cube_015969.png
# already seen
# CLEVR_yellow_sphere_brown_cube_015961.png
# CLEVR_yellow_sphere_brown_cube_015960.png
# CLEVR_yellow_sphere_brown_cube_015954.png
# CLEVR_yellow_sphere_brown_cube_015968.png
# already seen
# CLEVR_yellow_sphere_brown_cube_015973.png
# already seen
# CLEVR_yellow_sphere_brown_cube_015986.png
# already seen
# CLEVR_yellow_sphere_brown_cube_015997.png
# CLEVR_yellow_sphere_brown_cube_015989.png
# CLEVR_yellow_sphere_brown_cube_015995.png
# already seen
# yellow_sphere_brown_cone
# yellow sphere
# ...

# %%
# get two object zero-shot prompts
# !cp -r /content/drive/MyDrive/beth_two_obj_prompts/ /content/

# %%
# !cp -r /content/drive/MyDrive/gen_two_obj_prompts/ /content/

# %%
# !cp -r /content/drive/MyDrive/test_two_obj_prompts_gen/ /content/

# %%
# zero shot results
import clip
import torch
from PIL import Image
import glob
import os
import pandas as pd

def argmax(iterable):
    return max(enumerate(iterable), key=lambda x: x[1])[0]

device = "cuda" if torch.cuda.is_available() else "cpu"
model, transform = clip.load("ViT-B/32", device=device)
model.load_state_dict(torch.load("/content/drive/MyDrive/clip_two_object_5_seed_models/clip_two_seed_4.pt"))

correct = []

for clsname in os.listdir("two_object/val/"):
    rows_list = []
    print(clsname)
    #print(cls)
    prompt_file_name = clsname
    prompts = pd.read_csv('/content/gen_two_obj_prompts/'+prompt_file_name+'_gen.csv')
    class_names = prompts['class_name'].tolist()
    for c in class_names:
      print("'" + c + "'")
    #print(class_names)
    candidate_captions = [f"a photo of a {clsn}" for clsn in class_names]
    #print(candidate_captions)
    text = clip.tokenize(candidate_captions).to(device)
    class_correct = []
    clas = clsname.split("_")
    cls = clas[0] + " " + clas[1]
    test_imgs = glob.glob('two_object/val/'+clsname+'/' + cls + '/*.png')
    for img in test_imgs:
        #print(img)
        print("here")
        image = transform(Image.open(img)).unsqueeze(0).to(device)
        with torch.no_grad():
            image_features = model.encode_image(image)
            text_features = model.encode_text(text)

            logits_per_image, logits_per_text = model(image, text)
            probs = logits_per_image.softmax(dim=-1).cpu().numpy()

            pred = class_names[argmax(list(probs)[0])]

            print(pred)
            print(cls)

            dict1 = {'true': cls, 'pred': pred}
            rows_list.append(dict1)
            #print(pred)
            if pred == cls:
                correct.append(1)
                class_correct.append(1)
            else:
                correct.append(0)
                class_correct.append(0)

    print('accuracy on class ' + clsname + ' is :' + str(sum(class_correct)/len(class_correct)))
    df = pd.DataFrame(rows_list)
    df.to_csv('/content/clip_val_gen_two_obj_seed_4/' + prompt_file_name+'_output.csv')
print('accuracy on all is : ' + str(sum(correct)/len(correct)))
# Out:
# brown_sphere_gray_cylinder
# 'brown sphere'
# 'brown cylinder'
# 'gray sphere'
# 'cyan cone'
# 'yellow cube'
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# here
# brown sphere
# brown sphere
# ...

# %%
# !rm -r two_object.zip

# %%
# make test zero-shot prompts (and train)
import random
import pandas as pd
test_classes = ['red cube', 'green cube', 'purple cube', 'cyan cube', 'blue cylinder', 'brown cylinder', 'yellow cylinder', 'red cone', 'green cone', 'gray cone', 'blue cone']
train_classes = ['red sphere', 'green sphere', 'purple sphere', 'cyan sphere', 'gray sphere', 'blue sphere', 'yellow sphere', 'gray cube', 'blue cube', 'brown cube', 'red cylinder', 'green cylinder', 'purple cylinder', 'cyan cylinder', 'purple cone', 'brown cone', 'yellow cone']
for folder in os.listdir("two_object/test/"):
  print(folder)
  shape1 = folder.split("_")[0] + " " + folder.split("_")[1]
  print(shape1)
  rows = []
  classes_to_add = test_classes.copy()
  print(classes_to_add)
  print(classes_to_add)
  classes_to_add.remove(shape1)
  mydict = {'prompt': "a photo of a " + shape1, 'class_name': shape1, 'classidx': 0}
  rows.append(mydict)
  shape1color = shape1.split(" ")[0]
  shape1shape = shape1.split(" ")[1]
  # create list of classes to remove because removing as iterating messed up iteration
  classes_to_remove = []
  for c in classes_to_add:
    if shape1color in c:
      classes_to_remove.append(c)
    if shape1shape in c:
      classes_to_remove.append(c)

  for c in classes_to_remove:
    classes_to_add.remove(c)
  print(classes_to_add)
  # get a random class from test_classes
  for i in range(2):
    num = random.randint(0, len(classes_to_add)-1)
    shape2 = classes_to_add[num]
    mydict = {'prompt': "a photo of a " + shape2, 'class_name': shape2, 'classidx': i+1}
    rows.append(mydict)
    classes_to_add.remove(shape2)
    shape2color = shape2.split(" ")[0]
    shape2shape = shape2.split(" ")[1]
    classes_to_remove = []
    for c in classes_to_add:
      if shape2color in c:
        classes_to_remove.append(c)
      if shape2shape in c:
        classes_to_remove.append(c)
    for c in classes_to_remove:
      classes_to_add.remove(c)

  df = pd.DataFrame(rows)
  df.to_csv('/content/test_two_obj_prompts/'+folder+'.csv')
# Out:
# gray_cone_cyan_cube
# gray cone
# ['red cube', 'green cube', 'purple cube', 'cyan cube', 'blue cylinder', 'brown cylinder', 'yellow cylinder', 'red cone', 'green cone', 'gray cone', 'blue cone']
# ['red cube', 'green cube', 'purple cube', 'cyan cube', 'blue cylinder', 'brown cylinder', 'yellow cylinder', 'red cone', 'green cone', 'gray cone', 'blue cone']
# ['red cube', 'green cube', 'purple cube', 'cyan cube', 'blue cylinder', 'brown cylinder', 'yellow cylinder']
# cyan_cube_blue_cone
# cyan cube
# ['red cube', 'green cube', 'purple cube', 'cyan cube', 'blue cylinder', 'brown cylinder', 'yellow cylinder', 'red cone', 'green cone', 'gray cone', 'blue cone']
# ['red cube', 'green cube', 'purple cube', 'cyan cube', 'blue cylinder', 'brown cylinder', 'yellow cylinder', 'red cone', 'green cone', 'gray cone', 'blue cone']
# ['blue cylinder', 'brown cylinder', 'yellow cylinder', 'red cone', 'green cone', 'gray cone', 'blue cone']
# red_cube_gray_cone
# red cube
# ...

# %%
# make test generalsied zero-shot prompts (and train)
import random
import pandas as pd
test_classes = ['red cube', 'green cube', 'purple cube', 'cyan cube', 'blue cylinder', 'brown cylinder', 'yellow cylinder', 'red cone', 'green cone', 'gray cone', 'blue cone']
train_classes = ['red sphere', 'green sphere', 'purple sphere', 'cyan sphere', 'gray sphere', 'blue sphere', 'yellow sphere', 'gray cube', 'blue cube', 'brown cube', 'red cylinder', 'green cylinder', 'purple cylinder', 'cyan cylinder', 'purple cone', 'brown cone', 'yellow cone']
for folder in os.listdir("two_object/train/"):
  print(folder)
  shape1 = folder.split("_")[0] + " " + folder.split("_")[1]
  print(shape1)
  rows = []
  classes_to_add = train_classes.copy()
  print(classes_to_add)
  print(classes_to_add)
  classes_to_add.remove(shape1)
  mydict = {'prompt': "a photo of a " + shape1, 'class_name': shape1, 'classidx': 0}
  rows.append(mydict)
  shape1color = shape1.split(" ")[0]
  shape1shape = shape1.split(" ")[1]
  # create list of classes to remove because removing as iterating messed up iteration
  classes_to_remove = []
  for c in classes_to_add:
    if shape1color in c:
      classes_to_remove.append(c)
    if shape1shape in c:
      classes_to_remove.append(c)

  for c in classes_to_remove:
    classes_to_add.remove(c)
  print(classes_to_add)

  # add hard negative labels
  second_shape = folder.split("_")[2] + " " + folder.split("_")[3]
  secondshapecolor = second_shape.split(" ")[0]
  secondshapetype = second_shape.split(" ")[1]
  hard_neg1 = shape1color + " " + secondshapetype
  hard_neg2 = secondshapecolor + " " + shape1shape
  mydict = {'prompt': "a photo of a " + hard_neg1, 'class_name': hard_neg1, 'classidx': 1}
  rows.append(mydict)
  mydict = {'prompt': "a photo of a " + hard_neg2, 'class_name': hard_neg2, 'classidx': 2}
  rows.append(mydict)
  if hard_neg1 in classes_to_add:
    classes_to_add.remove(hard_neg1)
  if hard_neg2 in classes_to_add:
    classes_to_add.remove(hard_neg2)
  print(classes_to_add)

  # get a random class from test_classes
  for i in range(2):
    num = random.randint(0, len(classes_to_add)-1)
    shape2 = classes_to_add[num]
    mydict = {'prompt': "a photo of a " + shape2, 'class_name': shape2, 'classidx': i+3}
    rows.append(mydict)
    classes_to_add.remove(shape2)
    shape2color = shape2.split(" ")[0]
    shape2shape = shape2.split(" ")[1]
    classes_to_remove = []
    for c in classes_to_add:
      if shape2color in c:
        classes_to_remove.append(c)
      if shape2shape in c:
        classes_to_remove.append(c)
    for c in classes_to_remove:
      classes_to_add.remove(c)

  df = pd.DataFrame(rows)
  df.to_csv('/content/train_two_obj_prompts_gen/'+folder+'.csv')
# Out:
# red_sphere_purple_cylinder
# red sphere
# ['red sphere', 'green sphere', 'purple sphere', 'cyan sphere', 'gray sphere', 'blue sphere', 'yellow sphere', 'gray cube', 'blue cube', 'brown cube', 'red cylinder', 'green cylinder', 'purple cylinder', 'cyan cylinder', 'purple cone', 'brown cone', 'yellow cone']
# ['red sphere', 'green sphere', 'purple sphere', 'cyan sphere', 'gray sphere', 'blue sphere', 'yellow sphere', 'gray cube', 'blue cube', 'brown cube', 'red cylinder', 'green cylinder', 'purple cylinder', 'cyan cylinder', 'purple cone', 'brown cone', 'yellow cone']
# ['gray cube', 'blue cube', 'brown cube', 'green cylinder', 'purple cylinder', 'cyan cylinder', 'purple cone', 'brown cone', 'yellow cone']
# ['gray cube', 'blue cube', 'brown cube', 'green cylinder', 'purple cylinder', 'cyan cylinder', 'purple cone', 'brown cone', 'yellow cone']
# red_cylinder_blue_cube
# red cylinder
# ...
